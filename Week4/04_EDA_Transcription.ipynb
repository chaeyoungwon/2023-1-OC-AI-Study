# %% [markdown]
# https://www.kaggle.com/code/ash316/eda-to-prediction-dietanic/notebook

# %% [markdown]
# # EDA 필사

# %% [markdown]
# ![](./main.png)

# %% [markdown]
# 벌써 절반까지 달려오신 여러분! 너무 고생 많으셨습니다. 8주차에서 절반에 해당하는 4주차까지 모델링이 아닌 데이터에 대해 이렇게 시간을 쏟은 이유는 프로젝트를 수행할 때, 생각보다 데이터를 마음대로 다룰 수 있는 기본기가 중요하기 때문입니다.
#
#  그렇지 않으면, 남들이 깨끗하게 만들어 놓은 데이터셋만을 가지고 모델링을 해야하는데, 그런 사람과 어떤 데이터든 원하는 형태로 바꿔가며 모델에 맞출 수 있는 사람은 하늘과 땅차이라고 생각합니다. 그만큼 데이터 전처리와 EDA는 프로젝트에 있어 매우 중요한 역할을 하기 때문에, 시간을 조금 들이더라도 최대한 익숙해지는 과정을 여러분과 함께했습니다. 이번 주차엔 살짝 쉬어가는 느낌으로 `EDA 필사`를 진행합니다.
#
#  > **창작의 시작은 모방이다**
#
#  라는 말이 있죠? 누구나 처음부터 잘할 수는 없습니다. 다만, 잘하는 사람은 어떻게 하는지 보고 배울 수는 있죠. 이번 시간엔 우리가 지지난 시간에 다뤄봤던 `Titanic` 데이터를 가지고 고수는 어떻게 EDA를 했는지 하나하나 따라해보겠습니다.
#
# #### 필사? 그냥 코드 따라치는 거 아닌가요? 이게 의미가 있나요?
# 그냥 복붙을 하면 말씀하신 대로 정말 의미가 없습니다. 그러나 필사를 하게 되면 우리는 코드의 "흐름"을 함께 따라가면서 몰랐던 부분은 새로 알게 되고, 알았던 부분에 대한 확신을 가지게 됩니다. 필사는 단순한 노동이 아닌, 코드의 흐름을 따라가보고 익히는 과정으로 이해하시면 좋을 거 같습니다 ㅎㅎ
#
# <br>
#
# ---
# **알림**
# - 본 컨텐츠는 강의 형식이 아닌, 스스로 공부하시는 분들을 위한 일종의 문제집 입니다.
# - 데이터라는 큰 바다에서 여러분이 쓸 데 없는 시간 낭비 없이 바로바로 핵심을 배우실 수 있도록 커리큘럼을 짜봤습니다.
# - 이 컨텐츠의 문제들만 해결한다고 실력이 오르지 않습니다. 본 컨텐츠의 목적은 문제를 해결하는 과정에서 발생하는 고민과 질문을 통한 실력 향상입니다.
# - 문제에서 절대 떠먹여주지 않습니다. 물고기를 잡아주는 것이 아닌, 물고기를 잡는 방법을 여러분이 이 컨텐츠를 통해 알아가셨으면 합니다.
#
# <br>
#
# ### ❗주의❗
# > 이번 필사 컨텐츠는 복붙을 최대한 지양합니다. 물론 복붙을 하시는 것을 제가 막을 수는 없지만, 복붙을 하게 되면 이 컨텐츠는 그 순간부터 공부가 아닌 노동이 되어버립니다. 컨텐츠로부터 최대한 많은 공부를 하셨으면 하는 바람으로, 복붙은 최대한 삼가주시길 부탁드립니다.

# %% [markdown]
# # EDA 소개
# https://www.kaggle.com/code/ash316/eda-to-prediction-dietanic/notebook
#
# 이번 컨텐츠에서 필사해볼 EDA는 `EDA To Prediction(DieTanic)` 입니다. `Ashwini Swain`이라는 사람이 5년 전에 작성한 EDA인데, 사실 아직까지도 필사하면서 연습하기 좋은 EDA로 남아있습니다. 그만큼 모범적이었다는 거죠 ㅎㅎ
#
# 우리도 할 수 있습니다. 하나하나 따라가보면서 어떻게 했는지 알아보겠습니다.
#
# <br>
#
# <br>
#
# **🚩 필사를 하는 도중, `새로 알게된 것들`이나 `의문점`들은 코드 옆에 주석으로 표시해두시는 걸 추천드립니다! 나중에 뭘 배웠고 어떤 의문점이 들었는지를 정리할 때 많은 도움이 될 거예요!**
# _예시_
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('fivethirtyeight')  # plt.style을 지정해주면 신경 쓰지 않아도 알아서 이쁜 스타일을 고를 수 있다!!!!
# import warnings
# warnings.filterwarnings('ignore') # 쓸 데 없이 나오는 경고문들을 무시할 수 있다!
# %matplotlib inline # matplotlib의 결과물을 바로 확인할 수 있게 해주는 코드구나!
# ```

# %% [markdown]
# ## 관련 라이브러리 import

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight') 
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import numpy as np # numpy: C언어로 구현된 파이썬 라이브러리 - 고성능 수치계산, 다차원 배열 처리(수학적 연산)에 유용
import pandas as pd # pandas : 데이터 프레임과 시리즈 사용을 쉽게 해주는 라이브러리
import matplotlib.pyplot as plt # matplotlib.pyplot : 함수를 사용하여 간편하게 그래프 생성, 변화 모듈
import seaborn as sns # sns: python 시각화에 많이 사용되는 라이브러리로, matplotlib을 기반으로 한다.
plt.style.use('fivethirtyeight') # fivethirtyeight: 네이트실버 스타일, plt.style을 지정하면 알아서 스타일 변화!
import warnings
warnings.filterwarnings('ignore') # 경고문(원하는 값 확인 방해) 무시 기능
# %matplotlib inline
# matplotlib의 결과물을 바로 확인할 수 있게 해주는 코드

# %% [markdown]
# ### 데이터 불러오기 및 확인

# %%
data = pd.read_csv('./titanic.csv')
print(data.isnull().sum())
data.head()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data = pd.read_csv('./titanic.csv') # read_csv('파일명.csv') 형식으로 입력 가능, 파일 안에 한글이 포함되어 있을 경우 encoding = 'utf-8' 이용
print(data.isnull().sum()) # column별 결측값 개수 구하기
data.head() # 불러온 데이터의 상위 5개의 행 출력
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### 생존자 시각화 (Class 분포 확인)

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8)) 
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8)) # 2개의 ax를 가지는 하나의 figure 생성, 가로 세로 길이는 figsize로 설정
data['survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True) # value_counts().plot.pie: 속성에 대한 개수를 값으로 하여 그래프 생성
ax[0].set_title('survived')
ax[0].set_ylabel('')
sns.countplot('survived',data=data,ax=ax[1])
ax[1].set_title('survived')
plt.show()

# explode: 부채꼴이 중심에서 벗어나는 정도 표현, 여기서는 반지름의 10%만큼 벗어남
# shadow = True: 파이차트에 그림자 생성
# autopct: 부채꼴 안에 표시될 숫자의 형식 지정, 여기서는 소수점 한자리까지 표시
# ax = ax[index]작성 통해 그래프 위치 설정!!

# %% [markdown]
# 코드 필사를 통해 배운 지식, 의문점, 파악할 수 있는 정보 등을 자유롭게 적어주세요.
# * figure 와 ax 객체를 생성하는 방법
# - figure: 그래프를 그릴 공간
# - ax(axes): 이 공간 중에서 내가 지금 사용할 부분
#
# fig = plt.figure() : ax 없는 빈 figure 생성 (후에 ax를 추가해줘야함)
# fig, ax = plt.subplots() : 하나의 ax 만을 가지는 하나의 figure 생성
# fig, axes = plt.subplots(2,2) : 4개(2*2)이 ax들을 가지는 하나의 figure 생성

# %% [markdown]
# ### Feature와 Class 관계 파악하기

# %%
## 성별과 생존과의 관계

f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['sex','survived']].groupby(['sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('survived vs sex')
sns.countplot('sex',hue='survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# => 성별로 생존률 파악, 총 생존자, 사망자 추이 
# groupby(): 그룹별로 데이터를 집계
# mean(): 평균 계산
# hue: 두 가지 카테고리 값에 의한 실수 값의 변화를 보기 위한 hue 인수가 제공된다. hue 인수에 카테고리 값을 가지는 변수의 이름을 지정하면 카테고리 값에 따라 다르게 시각화된다
# countplot 명령을 사용하면 각 카테고리 값별로 데이터가 얼마나 있는지 표시할 수 있다.
# countplot 명령은 데이터프레임에만 사용할 수 있다. data 인수에는 대상이 되는 데이터프레임을, x 인수에는 데이터프레임의 열 이름 문자열을 넣는다.
# 그룹핑 후 바로 연산을 하면 그룹핑된 column들이 index 레벨에 내려간 채로 연산이 진행된다. 원본 dataframe과 새로운 dataframe이 생성된다.

# %%
## 선실 등급과 샌존과의 관계

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('pclass',hue='survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# 1번째: 티켓 등급별 승객 수
# 2번째: 티켓 등급별 사망자와 생존자

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
sns.factorplot('pclass','survived',hue='sex',data=data)
plt.show()
# factorplot = 꺾은선 그래프
# 만약 factorplot에 ax=ax[index]를 사용했을 시: factorplot은 figure-level이므로 ax 적용이 안돼 새로운 figure을 만든다.

# %% [markdown]
# 위의 2개의 그림과 `FactorPlot`을 고려했을 때, 어떤 사실을 알아낼 수 있나요?
# > pclass가 1등급일수록 생존자가 많고, 남자보다 여자 생존자가 더 많다.

# %% [markdown]
# ### Age 공략하기

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

print("# of Null Values of Age Column: ", data['Age'].isnull().sum())
# Out:
# # of Null Values of Age Column:  177

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10)) # range로 y축 범위 설정
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

print("# of Null Values of Age Column: ", data['Age'].isnull().sum())


# violinplot: kdeplot + boxplot
# 가운데 흰색 점은 중앙값이며, 중앙의 두꺼운 선은 사분위 범위를 나타낸다.
# 중심선을 따라 대칭인 kdeplot이 있다.
# 중앙의 얇은 선은 신뢰 구간을 나타낸다.
# Out:
# # of Null Values of Age Column:  177

# %% [markdown]
# 📌한번 같이 생각해봐요!📌
# 아래는 Age Column에 비어있는 177개의 값을 채우기 위한 아이디어 입니다.
#
# 이 분은 Age에 비어 있는 값을 채워주기 위해, 평균값을 이용하여 채워주려고 했지만,
# 위의 시각화 자료를 보아하니, 연령대의 분포가 너무 다양하여 평균값 하나로만 채우기 애매했죠.
# 단순히 평균값으로 채워버리면, 4세의 정보에 평균값인 29살을 넣어버리는 경우가 발생할 수 있었습니다.
#
# 이를 해결하기 위한 아이디어로 저자는 `Name`에서 그 힌트를 활용하기로 합니다.
# `Name`을 잘 보면, *mr*, *mrs* 와 같이 이름에 대한 정보로 데이터를 구분할 수 있다는 사실을 알아낼 수 있습니다.
#
# 즉!!!! Age의 null 값을 단순 평균치가 아닌, 이름에서 힌트를 얻어 이들의 평균값으로 대체하면, 조금 더 세밀한 결측치 제거가 가능하다는 것이죠!
#
# 한번 어떻게 했는지 따라가봅시다 :)

# %%
## 먼저, 이름에서 특정한 부분을 추출해봅시다.
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') # 이 정규식은 무엇을 의미할까요? 헷갈리면... 정규식 고수 유우비트님께 물어봅시다..! ㅎㅎ
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')
data

# 정규식: 특정한 규칙을 가진 문자열을 검색, 치환하기 위해 사용
# []안에 -를 사용하여 문자 사이의 범위를 표현
# +는 앞의 문자를 1번 이상 반복하는 것을 의미
# ''([a-zA-Z]+)\.': 띄어쓰기로 시작해 모든 알파벳이 포함된 문자열을 한 번이상 반복하다가 dot(.)으로 마무리하는 문자열
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## 뽑아낸 이니셜이 성별로 어떤 분포를 가지고 있는지 표로 살펴봅시다
pd.crosstab(data.Initial,data.Sex).T
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
pd.crosstab(data.Initial,data.Sex).T 
# crosstab: 범주형 변수를 기준으로 개수 파악이나 수치형 데이터를 넣어 계산할 때 사용
# 필수 input: index. columns
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
## 일부 발생한 오타를 replace 함수를 통해 정리해줍니다.
data['Initial'].replace(
    ['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
    ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],
    inplace=True)
print(data.groupby('Initial')['Age'].mean()) # 평균값 확인!
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
data['Initial'].replace(
    ['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
    ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],
    inplace=True)
print(data.groupby('Initial')['Age'].mean())

# inplace = True를 적용해야만 변경값이 적용됨.
# 출력값: Initial 그룹의 age 평균은?
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# 이제 각 이니셜 별로 평균 나이를 알아냈으니, 각 평균값에 맞게 채워줍니다.
# pandas에서 배웠던 loc는 이런 식으로 활용됩니다 :)
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

print("결측치 제거 후 남은 결측치: ",data.Age.isnull().sum())
# Out:
# 결측치 제거 후 남은 결측치:  0

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'age']=46

print("결측치 제거 후 남은 결측치: ",data.Age.isnull().sum())

# 결측치가 왜 0이 아닐까요 . . .
# Out:
# 결측치 제거 후 남은 결측치:  177

# %%
## 최종 생존여부 별 연령대 확인
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red') #bins은 막대그래프의 폭을 의미
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1) #리스트를 만들어 x축 범위로 지정하는 것도 가능하다
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show() #결측치가 0이 아니라 그래프에 차이가 있다..

# %% [markdown]
# 위의 과정에서 어떤 걸 알 수 있었나요? 추가적으로 아래의 질문에도 답을 달아보세요!
# - 영아(5세 미만)들은 최우선적으로 구해진 것같나요?
# - 생존자 중, 가장 나이가 많은 사람은 몇 세인가요?
# - 가장 많이 죽음을 당한 연령대는 몇 세인가요?
# > 1.네 2.80세 3.20대

# %% [markdown]
# ### 탑승항구와 생존여부

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf() #  현재 figure를 확인하기 위한 방법으로는 plt.gcf()를 사용한다. gcf는 get current figure의 약어로,각각의 plt.gcf() 출력 결과가 어떻게 바뀌는지 알 수 있다.
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

#1. 탑승객 수
#2. 성별에 따른 탑승객 수
#3. 탑승객 중 생존자와 사망자
#4. pclass에 따른 탑승객 수
# subplots_adjust(left, bottom, right, top, wspace, hspace): 현재 배치되어 있는 subplot들의 위치를 직접 조정한다.
# left, bottom, right, top : 서브플롯 4면의 위치 조정
# hspace, wspace: 서브플롯 간의 간격을 위해 각각 figure의 너비와 높이에 대한 비율 조절

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()
# x축: pclass, y축: 생존자 수, sex에 따른 데이터 표현 (hue 통해 그래프 두 개 구현), 선착장 3개이므로 그래프 3개 생성)

# %% [markdown]
# 탑승 선착장의 종류별로 다른 Feature들과 함께 비교해봤습니다. 어떤 점을 여기서 유추해볼 수 있나요? 다음의 질문에 대답해보면서 답을 적어보세요!
# - 가장 많은 승객이 탑승한 선착장은 어디고, 대부분 몇 등급의 선실이었나요?
# - 마지막 그림에서, S 선착장에서 알아낼 수 있는 사실은 무엇인가요?
# > S, 3등급
# 1등급에 탑승한 여자 탑승객이 많이 살아남았고, 3등급은 그에 비해 많은 사망자가 발생했다. 남자 탑승객은 여자 탑승객에 비해 많이 생존하지 못했다.

# %% [markdown]
# ## 4주차 종료
# - 절반까지 달려오신 여러분! 모두 고생 많으셨습니다.
# - 이번 EDA 필사를 진행하면서, 고수의 인사이트와 기술을 많이 배우신 분도 계실 거고, 단순 노동으로 느껴지신 분들도 계실 거 같습니다
# - 2주에 걸쳐 EDA를 한 이유는, 데이터 수집부터 배포까지 이루어지는 모델의 Cycle에서 앞으로의 방향성과 남들과 차별화를 둘 수 있는 전략이 바로 대부분 EDA에서 나오기 때문입니다. (Dacon이나 Kaggle만 들어가보셔도 금방 공감하실 수 있을 거예요!)
# - **다음주부터 본격적으로 ML 컨텐츠에 들어갑니다.**
# - ML은 총 3주에 걸쳐 진행될 예정으로, 다음 컨텐츠는 시험기간이기도 하니, 머신러닝의 전반적인 플로우를 함께 따라가보면서 어떤 녀석인지 확인해보는 시간을 가져보겠습니다 ㅎㅎ
#
# <br>
#
# ## 숙제
# - 이번 컨텐츠 숙제는 간단합니다.
# - `여러분이 EDA 필사를 진행하면서 새로 알게 된 내용이나 깨달은 내용을 블로그에 정리`해주세요!
# - 추천 방법은 코드 하나하나를 따라가시면서 주석 다셨던 내용을 기반으로 _이 코드는 이런 원리로 작동하는 구나!_ 혹은 _아 이 분은 이 데이터에서 이런 인사이트를 얻었구나!_ 혹은 _이렇게 굳이 안 해도 요렇게 해도 될 거 같은데?_ 와 같은 내용들을 작성하시는 것을 추천드립니다 ㅎㅎ
#
#
# <br>
#
# ### 📄난이도 조사📄
# - 전체 커리큘럼의 절반을 지나면서, 어떤 분들은 쉽게, 어떤 분들은 너무 어렵게 느껴졌을 수 있습니다.
# - 다음 컨텐츠부터는 본격적으로 머신러닝에 대해 진행되는 만큼, 난이도 조절에 대한 설문을 받고자 합니다.
# - [이곳](https://forms.gle/yBpjFrGKQDWUin5E9)에 들어가셔서 4주차에 걸친 데이터 분석 내용의 난이도가 어땠는지 간단하게 답변해주세요!
#
# <br>
#
# ### 질문은 언제나 환영입니다!
